# %%
#LSTM

# %%
import pandas as pd

# Read the data set
data = pd.read_csv("new_df_selected5_last5years_adjusted.csv")


unique_company_names = data['company_name'].nunique()
unique_status_labels = data['status_label'].nunique()
unique_divisions = data['Division'].nunique()
unique_majorgroup = data['MajorGroup'].nunique()
unique_last_year = data['last_year'].nunique()

print("Number of unique values in 'company_name' column:", unique_company_names)
print("Number of unique values in 'status_label' column:", unique_status_labels)
print("Number of unique values in 'Division' column:", unique_divisions)
print("Number of unique values in 'MajorGroup' column:", unique_majorgroup)
print("Number of unique values in 'last_year' column:", unique_last_year)
# Out:
# Number of unique values in 'company_name' column: 8971
# Number of unique values in 'status_label' column: 2
# Number of unique values in 'Division' column: 10
# Number of unique values in 'MajorGroup' column: 73
# Number of unique values in 'last_year' column: 20

# %%
data.shape
# Out:
# (8971, 195)

# %%
# Encoding non-numeric columns

from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder object
label_encoder = LabelEncoder()


# Label-encode the company_name column
data['company_name_encoded'] = label_encoder.fit_transform(data['company_name'])


# Label-encode the Division column
data['Division_encoded'] = label_encoder.fit_transform(data['Division'])

# Label-encode MajorGroup columns
data['MajorGroup_encoded'] = label_encoder.fit_transform(data['MajorGroup'])
#When using label encoding for feature encoding, the sequential relationship between categories will not be introduced and will not have an impact on prediction.

# Encode the label of the status_label column
data['status_label_encoded'] = label_encoder.fit_transform(data['status_label'])
#With only two categories, it may be simpler and more appropriate to use label encoding as it maps the categories to 0 and 1, suitable for use in tree-based models. 
#If use one-hot encoding, a new column will be generated

print(data.head())
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#   company_name status_label Division  MajorGroup  last_year  X1_last1year  \
# 0          C_1        alive        D          37     2017.0         942.7
# 1          C_2        alive        D          36     2010.0        1107.7
# 2          C_3        alive        D          38     2008.0       12686.0
# 3          C_4        alive        D          28     2007.0      581502.0
# 4          C_5        alive        D          35     1999.0       28957.0
#
#    X1_last2year  X1_last3year  X1_last4year  X1_last5year  ...  \
# 0         888.5         873.1         954.1      1116.900  ...
# 1         900.2        1077.4        1008.2       942.700  ...
# 2       13454.0       13582.0        7726.0      5807.000  ...
# 3      353541.0     1037047.0      672072.0       692.991  ...
# 4           NaN           NaN           NaN           NaN  ...
#
#    nyse_last5year  nasdaq_last1year  nasdaq_last2year  nasdaq_last3year  \
# 0     9467.185872       6293.024211       5015.926717       4932.729126
# 1     8434.441610       2333.908345       1856.529999       2148.948334
# 2     6645.525065       2148.948334       2587.587504       2278.996664
# 3     5478.855835       2587.587504       2278.996664       2100.603343
# 4             NaN       2787.559998               NaN               NaN
#
#    nasdaq_last4year  nasdaq_last5year  company_name_encoded  Division_encoded  \
# 0       4414.850057       3575.141642                     0                 3
# 1       2587.587504       2278.996664                  1111                 3
# 2       2100.603343       1992.867482                  2222                 3
# 3       1992.867482       1659.239176                  3333                 3
# 4               NaN               NaN                  4444                 3
#
#    MajorGroup_encoded  status_label_encoded
# 0                  29                     0
# 1                  28                     0
# 2                  30                     0
# 3                  20                     0
# 4                  27                     0
#
# [5 rows x 199 columns]

# %%
data.shape
# Out:
# (8971, 199)

# %%
missing_rows_count = data.isnull().any(axis=1).sum()
print("Number of rows with missing values:", missing_rows_count)
# Out:
# Number of rows with missing values: 3993

# %%
# Delete rows with missing values
data_cleaned = data.dropna()
# Delete non-numeric columns that are not encoded
# List of static columns to drop
static_columns_to_drop = [
    'company_name', 'status_label', 'Division', 'MajorGroup', 'last_year', 'company_name_encoded',
    'Division_encoded', 'MajorGroup_encoded'
]

# List of dynamic columns to drop (nyse and nasdaq columns for 1 year and 2 years)
nyse_nasdaq_columns_to_drop = [f'{exchange}_last{year}year' for exchange in ('nyse', 'nasdaq') for year in (1, 2, 3, 4, 5)]

# Add X1_last1year_ycr to X18_last1year_ycr and X1_last2year_ycr to X18_last2year_ycr columns to the list
ycr_columns_to_drop = [f'X{i}_last{year}year_ycr' for i in range(1, 19) for year in (1, 2, 3, 4, 5)]

# Combine all columns to drop
columns_to_drop = static_columns_to_drop + nyse_nasdaq_columns_to_drop + ycr_columns_to_drop

# Drop the columns from the data
data_cleaned = data_cleaned.drop(columns=columns_to_drop)


data_cleaned.shape
# Out:
# (4978, 91)

# %%
data_cleaned.head
# Out:
# <bound method NDFrame.head of       X1_last1year  X1_last2year  X1_last3year  X1_last4year  X1_last5year  \
# 0           942.70        888.50       873.100         954.1      1116.900
# 1          1107.70        900.20      1077.400        1008.2       942.700
# 3        581502.00     353541.00   1037047.000      672072.0       692.991
# 5          6838.00       6642.00      5935.000        7229.0      6902.000
# 6        160865.00     173942.00    212978.000      228456.0    142967.000
# ...            ...           ...           ...           ...           ...
# 8959       8218.00         21.33     16699.000       18523.0     16814.000
# 8963        362.33     310358.00    405282.000      359824.0    331465.000
# 8965      22026.00      26515.00        13.256        1801.0      5941.000
# 8966      10566.00      11738.00      9599.000        9789.0     11645.000
# 8969        931.60       1032.70       829.300         735.1       973.800
#
#       X2_last1year  X2_last2year  X2_last3year  X2_last4year  X2_last5year  \
# 0           1524.7      1504.100      1442.100        1515.0      2199.500
# 1           1474.5      1343.600      1921.000        1764.8      1611.400
# 3        1288165.0    927239.000      1623.383     2003842.0   2329268.000
# 5          25088.0     25438.000     25175.000       28571.0     29145.000
# 6         392582.0    438549.000    498634.000      598819.0    414365.000
# ...            ...           ...           ...           ...           ...
# 8959       10814.0        24.830     25102.000       28339.0     28369.000
# 8963      471155.0       425.563    529043.000      489109.0       461.488
# 8965       28813.0     36646.000     19899.000       16574.0     23139.000
# 8966       28278.0     26206.000     23442.000       22757.0     24283.000
# 8969        2810.2      2542.000      2247.400        2285.3      2015.900
#
#       ...  X17_last2year  X17_last3year  X17_last4year  X17_last5year  \
# 0     ...         1767.6         1662.6        1594.30         2035.0
# 1     ...          996.7         1456.4        1322.20         1281.9
# 3     ...       653828.0       553617.0        1339.48      1297285.0
# 5     ...        19917.0        23766.0       22896.00        22563.0
# 6     ...       345051.0       417011.0      367422.00       263217.0
# ...   ...            ...            ...            ...            ...
# 8959  ...        36839.0        39738.0       41231.00        55284.0
# 8963  ...       275026.0       253193.0      299611.00       341838.0
# 8965  ...        47824.0         6574.0         932.00          628.0
# 8966  ...        34484.0        29183.0       32735.00        45608.0
# 8969  ...         2408.2         2238.0        2068.10         2118.3
#
#       X18_last1year  X18_last2year  X18_last3year  X18_last4year  \
# 0          1621.800         1619.4        1525.70         1510.6
# 1          1035.200          912.0        1283.10         1154.3
# 3           681.609       514914.0      390516.00      1185651.0
# 5         20867.000        19655.0       23256.00        20803.0
# 6        310005.000       316986.0      360792.00       322251.0
# ...             ...            ...            ...            ...
# 8959      34037.000        44487.0       47651.00        46983.0
# 8963     216602.000       253495.0      205824.00       242535.0
# 8965      49355.000        64084.0          21.19        13011.0
# 8966      32459.000        27850.0       23059.00        25531.0
# 8969       2112.700         1840.9        1748.00         1624.0
#
#       X18_last5year  status_label_encoded
# 0            1779.0                     0
# 1            1141.5                     0
# 3         1142057.0                     0
# 5           20346.0                     1
# 6          227617.0                     0
# ...             ...                   ...
# 8959        57025.0                     0
# 8963       276704.0                     0
# 8965        15996.0                     0
# 8966        38905.0                     0
# 8969         1679.0                     0
#
# [4978 rows x 91 columns]>

# %%
status_counts = data_cleaned['status_label_encoded'].value_counts()
print(status_counts)
# Out:
# 0    4548
# 1     430
# Name: status_label_encoded, dtype: int64

# %%
#the impact of imbalanced datasets

# %% [markdown]
# ### 1.1 imbalance dataset

# %%
# Feature column names
last1year_features = []
last2year_features = []
last3year_features = []
last4year_features = []
last5year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')
    last3year_features.append(f'X{i}_last3year')
    last4year_features.append(f'X{i}_last4year')
    last5year_features.append(f'X{i}_last5year')



# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
X_last3year = data_cleaned[last3year_features].values
X_last4year = data_cleaned[last4year_features].values
X_last5year = data_cleaned[last5year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of X_last3year:", X_last3year.shape)
print("Shape of X_last4year:", X_last4year.shape)
print("Shape of X_last5year:", X_last5year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year, X_last3year, X_last4year,  X_last5year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)
X_last3year_scaled = scaler.transform(X_last3year)
X_last4year_scaled = scaler.transform(X_last4year)
X_last5year_scaled = scaler.transform(X_last5year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))
X_last3year_reshaped = np.reshape(X_last3year_scaled, (X_last3year_scaled.shape[0], 1, X_last3year_scaled.shape[1]))
X_last4year_reshaped = np.reshape(X_last4year_scaled, (X_last4year_scaled.shape[0], 1, X_last4year_scaled.shape[1]))
X_last5year_reshaped = np.reshape(X_last5year_scaled, (X_last5year_scaled.shape[0], 1, X_last5year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last5year_reshaped, X_last4year_reshaped, X_last3year_reshaped, X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_last3year_scaled:", X_last3year_scaled.shape)
print("Shape of X_last4year_scaled:", X_last4year_scaled.shape)
print("Shape of X_last5year_scaled:", X_last5year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)



# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)




from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(5, X_train.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (4978, 18)
# Shape of X_last2year: (4978, 18)
# Shape of X_last3year: (4978, 18)
# Shape of X_last4year: (4978, 18)
# Shape of X_last5year: (4978, 18)
# Shape of y: (4978,)
# Shape of X_last1year_scaled: (4978, 18)
# Shape of X_last2year_scaled: (4978, 18)
# Shape of X_last3year_scaled: (4978, 18)
# Shape of X_last4year_scaled: (4978, 18)
# Shape of X_last5year_scaled: (4978, 18)
# Shape of X_combined_reshaped: (4978, 5, 18)
# Shape of X_train: (2986, 5, 18)
# Shape of X_val: (996, 5, 18)
# Shape of X_test: (996, 5, 18)
# Epoch 1/100
# 187/187 - 3s - 16ms/step - accuracy: 0.8958 - loss: 0.3240 - val_accuracy: 0.9056 - val_loss: 0.2919
# Epoch 2/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9200 - loss: 0.2589 - val_accuracy: 0.9076 - val_loss: 0.2911
# Epoch 3/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9213 - loss: 0.2544 - val_accuracy: 0.9066 - val_loss: 0.2811
# Epoch 4/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9220 - loss: 0.2463 - val_accuracy: 0.9076 - val_loss: 0.2803
# Epoch 5/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9226 - loss: 0.2442 - val_accuracy: 0.9076 - val_loss: 0.2788
# Epoch 6/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9236 - loss: 0.2402 - val_accuracy: 0.9086 - val_loss: 0.2782
# Epoch 7/100
# 187/187 - 1s - 4ms/step - accuracy: 0.9240 - loss: 0.2395 - val_accuracy: 0.9046 - val_loss: 0.2791
# Epoch 8/100
# 187/187 - 1s - 5ms/step - accuracy: 0.9257 - loss: 0.2328 - val_accuracy: 0.9066 - val_loss: 0.2764
# Epoch 9/100
# 187/187 - 1s - 5ms/step - accuracy: 0.9240 - loss: 0.2306 - val_accuracy: 0.9066 - val_loss: 0.2722
# Epoch 10/100
# 187/187 - 1s - 5ms/step - accuracy: 0.9267 - loss: 0.2251 - val_accuracy: 0.9056 - val_loss: 0.2718
# Epoch 11/100
# 187/187 - 1s - 4ms/step - accuracy: 0.
# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Accuracy: 0.9036144578313253
# Recall: 0.13402061855670103
# Precision: 0.52
# F1 Score: 0.21311475409836064
# Micro F1 Score: 0.9036144578313253
# Macro F1 Score: 0.5808889278513194
# ROC AUC: 0.6783138194786877
# Confusion Matrix:
# [[887  12]
#  [ 84  13]]

# %% [markdown]
# ### 1.2 SMOTE

# %%
# Feature column names
last1year_features = []
last2year_features = []
last3year_features = []
last4year_features = []
last5year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')
    last3year_features.append(f'X{i}_last3year')
    last4year_features.append(f'X{i}_last4year')
    last5year_features.append(f'X{i}_last5year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
X_last3year = data_cleaned[last3year_features].values
X_last4year = data_cleaned[last4year_features].values
X_last5year = data_cleaned[last5year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of X_last3year:", X_last3year.shape)
print("Shape of X_last4year:", X_last4year.shape)
print("Shape of X_last5year:", X_last5year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year, X_last3year, X_last4year,  X_last5year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)
X_last3year_scaled = scaler.transform(X_last3year)
X_last4year_scaled = scaler.transform(X_last4year)
X_last5year_scaled = scaler.transform(X_last5year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))
X_last3year_reshaped = np.reshape(X_last3year_scaled, (X_last3year_scaled.shape[0], 1, X_last3year_scaled.shape[1]))
X_last4year_reshaped = np.reshape(X_last4year_scaled, (X_last4year_scaled.shape[0], 1, X_last4year_scaled.shape[1]))
X_last5year_reshaped = np.reshape(X_last5year_scaled, (X_last5year_scaled.shape[0], 1, X_last5year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last5year_reshaped, X_last4year_reshaped, X_last3year_reshaped, X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_last3year_scaled:", X_last3year_scaled.shape)
print("Shape of X_last4year_scaled:", X_last4year_scaled.shape)
print("Shape of X_last5year_scaled:", X_last5year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)



# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)



from imblearn.over_sampling import SMOTE
# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply SMOTE only on the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 5, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)



from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(5, X_train_resampled.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (4978, 18)
# Shape of X_last2year: (4978, 18)
# Shape of X_last3year: (4978, 18)
# Shape of X_last4year: (4978, 18)
# Shape of X_last5year: (4978, 18)
# Shape of y: (4978,)
# Shape of X_last1year_scaled: (4978, 18)
# Shape of X_last2year_scaled: (4978, 18)
# Shape of X_last3year_scaled: (4978, 18)
# Shape of X_last4year_scaled: (4978, 18)
# Shape of X_last5year_scaled: (4978, 18)
# Shape of X_combined_reshaped: (4978, 5, 18)
# Shape of X_train: (2986, 5, 18)
# Shape of X_val: (996, 5, 18)
# Shape of X_test: (996, 5, 18)
# Shape of X_train_resampled: (5494, 90)
# Shape of X_train_resampled: (5494, 5, 18)
# Epoch 1/100
# 344/344 - 4s - 10ms/step - accuracy: 0.6560 - loss: 0.6094 - val_accuracy: 0.7861 - val_loss: 0.5486
# Epoch 2/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7015 - loss: 0.5477 - val_accuracy: 0.8293 - val_loss: 0.4816
# Epoch 3/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7284 - loss: 0.5128 - val_accuracy: 0.8775 - val_loss: 0.4128
# Epoch 4/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7343 - loss: 0.4950 - val_accuracy: 0.5733 - val_loss: 0.5809
# Epoch 5/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7495 - loss: 0.4700 - val_accuracy: 0.8032 - val_loss: 0.4782
# Epoch 6/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7601 - loss: 0.4535 - val_accuracy: 0.7570 - val_loss: 0.5191
# Epoch 7/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7630 - loss: 0.4401 - val_accuracy: 0.5341 - val_loss: 0.6981
# Epoch 8/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7727 - loss: 0.4357 - val_accuracy: 0.6687 - val_loss: 0.5414
# Epoch 9/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7845 - loss: 0.4167 - val_accuracy: 0.6627 - val_loss: 0.5635
# Epoch 10/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7903 - loss: 0.4074 - val_accuracy: 0.7992 - val_loss: 0.4899
# Epoch 11/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7949 - loss: 0.4044 - val_accuracy: 0.8233 - val_loss: 0.4677
# Epoch 12/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7987 - loss: 0.3909 - val_accuracy: 0.7098 - val_loss: 0.5856
# Epoch 13/100
# 344/344 - 1s - 4ms/step - accuracy: 0.7994 - loss: 0.3888 - val_accuracy: 0.8052 - val_loss: 0.5241
# Epoch 14/100
# 344/344 - 2s - 5ms/step - accuracy: 0.8041 - loss: 0.3770 - val_accuracy: 0.8755 - val_loss: 0.4541
# Epoch 15/100
# 344/344 - 1s - 4ms/step - accuracy: 0.8138 - loss: 0.3678 - val_accuracy: 0.6436 - val_loss: 0.6390
# Epoch 16/100
# 344/344 - 1s - 4ms/step - accuracy: 0.8112 - loss: 0.3678 - val_accuracy: 0.8002 - val_loss: 0.5400
# Epoch 17/100
# 344/344 - 1s - 4ms/step - accuracy: 0.8202 - loss: 0.3602 - val_accuracy: 0.6195 - val_loss: 0.6839
# Epoch 18/100
# 344/344 - 1s - 4ms/step - accuracy: 0.8118 - loss: 0.3583 - val_accuracy: 0.7821 - val_loss: 0.5889
# Epoch 19/100
# 344/344 - 1s - 4ms/step - accuracy: 0.8203 - loss: 0.3489 - val_accuracy: 0.6135 - val_loss: 0.7153
# Epoch 20/100
# 344/344 - 1s - 4ms/step - accuracy: 0.
100
# 344/344 - 1s - 4ms/step - accuracy: 0.9041 - loss: 0.2014 - val_accuracy: 0.8504 - val_loss: 0.8505
# Epoch 81/100
# 344/344 - 1s - 3ms/step - accuracy: 0.9024 - loss: 0.2007 - val_accuracy: 0.8414 - val_loss: 0.8775
# Epoch 82/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9063 - loss: 0.1940 - val_accuracy: 0.8353 - val_loss: 0.8769
# Epoch 83/100
# 344/344 - 1s - 3ms/step - accuracy: 0.9010 - loss: 0.2054 - val_accuracy: 0.8454 - val_loss: 0.8695
# Epoch 84/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9099 - loss: 0.1930 - val_accuracy: 0.7771 - val_loss: 0.9301
# Epoch 85/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9046 - loss: 0.1956 - val_accuracy: 0.8635 - val_loss: 0.8772
# Epoch 86/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9130 - loss: 0.1840 - val_accuracy: 0.8303 - val_loss: 0.8795
# Epoch 87/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9013 - loss: 0.1951 - val_accuracy: 0.8002 - val_loss: 0.9260
# Epoch 88/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9081 - loss: 0.1944 - val_accuracy: 0.8484 - val_loss: 0.8949
# Epoch 89/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9075 - loss: 0.1910 - val_accuracy: 0.7520 - val_loss: 0.9536
# Epoch 90/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9126 - loss: 0.1825 - val_accuracy: 0.8504 - val_loss: 0.9163
# Epoch 91/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9044 - loss: 0.1895 - val_accuracy: 0.8394 - val_loss: 0.9287
# Epoch 92/100
# 344/344 - 2s - 4ms/step - accuracy: 0.9115 - loss: 0.1850 - val_accuracy: 0.8253 - val_loss: 0.9333
# Epoch 93/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9081 - loss: 0.1849 - val_accuracy: 0.8514 - val_loss: 0.8998
# Epoch 94/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9161 - loss: 0.1763 - val_accuracy: 0.8554 - val_loss: 0.9099
# Epoch 95/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9130 - loss: 0.1787 - val_accuracy: 0.7420 - val_loss: 1.0202
# Epoch 96/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9152 - loss: 0.1789 - val_accuracy: 0.8313 - val_loss: 0.9513
# Epoch 97/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9190 - loss: 0.1727 - val_accuracy: 0.8845 - val_loss: 0.8879
# Epoch 98/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9148 - loss: 0.1745 - val_accuracy: 0.8454 - val_loss: 0.9620
# Epoch 99/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9203 - loss: 0.1797 - val_accuracy: 0.8715 - val_loss: 0.9889
# Epoch 100/100
# 344/344 - 1s - 4ms/step - accuracy: 0.9170 - loss: 0.1751 - val_accuracy: 0.8143 - val_loss: 0.9643
# test loss: 1.1108157634735107
# Test accuracy: 0.805220901966095

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Accuracy: 0.8052208835341366
# Recall: 0.3711340206185567
# Precision: 0.21301775147928995
# F1 Score: 0.27067669172932335
# Micro F1 Score: 0.8052208835341366
# Macro F1 Score: 0.5791390411137927
# ROC AUC: 0.6681421510727842
# Confusion Matrix:
# [[766 133]
#  [ 61  36]]

# %% [markdown]
# ### 1.3  Undersampling

# %%
# Feature column names
last1year_features = []
last2year_features = []
last3year_features = []
last4year_features = []
last5year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')
    last3year_features.append(f'X{i}_last3year')
    last4year_features.append(f'X{i}_last4year')
    last5year_features.append(f'X{i}_last5year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
X_last3year = data_cleaned[last3year_features].values
X_last4year = data_cleaned[last4year_features].values
X_last5year = data_cleaned[last5year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of X_last3year:", X_last3year.shape)
print("Shape of X_last4year:", X_last4year.shape)
print("Shape of X_last5year:", X_last5year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year, X_last3year, X_last4year,  X_last5year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)
X_last3year_scaled = scaler.transform(X_last3year)
X_last4year_scaled = scaler.transform(X_last4year)
X_last5year_scaled = scaler.transform(X_last5year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))
X_last3year_reshaped = np.reshape(X_last3year_scaled, (X_last3year_scaled.shape[0], 1, X_last3year_scaled.shape[1]))
X_last4year_reshaped = np.reshape(X_last4year_scaled, (X_last4year_scaled.shape[0], 1, X_last4year_scaled.shape[1]))
X_last5year_reshaped = np.reshape(X_last5year_scaled, (X_last5year_scaled.shape[0], 1, X_last5year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last5year_reshaped, X_last4year_reshaped, X_last3year_reshaped, X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_last3year_scaled:", X_last3year_scaled.shape)
print("Shape of X_last4year_scaled:", X_last4year_scaled.shape)
print("Shape of X_last5year_scaled:", X_last5year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)


# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)



from imblearn.under_sampling import RandomUnderSampler

# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply undersampling only on the training set
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 5, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)




from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(5, X_train_resampled.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (4978, 18)
# Shape of X_last2year: (4978, 18)
# Shape of X_last3year: (4978, 18)
# Shape of X_last4year: (4978, 18)
# Shape of X_last5year: (4978, 18)
# Shape of y: (4978,)
# Shape of X_last1year_scaled: (4978, 18)
# Shape of X_last2year_scaled: (4978, 18)
# Shape of X_last3year_scaled: (4978, 18)
# Shape of X_last4year_scaled: (4978, 18)
# Shape of X_last5year_scaled: (4978, 18)
# Shape of X_combined_reshaped: (4978, 5, 18)
# Shape of X_train: (2986, 5, 18)
# Shape of X_val: (996, 5, 18)
# Shape of X_test: (996, 5, 18)
# Shape of X_train_resampled: (478, 90)
# Shape of X_train_resampled: (478, 5, 18)
# Epoch 1/100
# 30/30 - 2s - 74ms/step - accuracy: 0.5921 - loss: 0.6704 - val_accuracy: 0.3333 - val_loss: 0.6940
# Epoch 2/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6632 - loss: 0.6313 - val_accuracy: 0.7480 - val_loss: 0.6404
# Epoch 3/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6527 - loss: 0.6087 - val_accuracy: 0.5914 - val_loss: 0.6694
# Epoch 4/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6862 - loss: 0.5908 - val_accuracy: 0.7701 - val_loss: 0.6115
# Epoch 5/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6653 - loss: 0.5785 - val_accuracy: 0.4247 - val_loss: 0.7119
# Epoch 6/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6841 - loss: 0.5698 - val_accuracy: 0.7510 - val_loss: 0.6404
# Epoch 7/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7134 - loss: 0.5588 - val_accuracy: 0.7410 - val_loss: 0.6335
# Epoch 8/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7050 - loss: 0.5547 - val_accuracy: 0.6245 - val_loss: 0.6796
# Epoch 9/100
# 30/30 - 0s - 9ms/step - accuracy: 0.6987 - loss: 0.5466 - val_accuracy: 0.6506 - val_loss: 0.6615
# Epoch 10/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7092 - loss: 0.5356 - val_accuracy: 0.5231 - val_loss: 0.6738
# Epoch 11/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7008 - loss: 0.5320 - val_accuracy: 0.5040 - val_loss: 0.7063
# Epoch 12/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7280 - loss: 0.5286 - val_accuracy: 0.6285 - val_loss: 0.6761
# Epoch 13/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7218 - loss: 0.5208 - val_accuracy: 0.8203 - val_loss: 0.5586
# Epoch 14/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7280 - loss: 0.5208 - val_accuracy: 0.8173 - val_loss: 0.5743
# Epoch 15/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7259 - loss: 0.5170 - val_accuracy: 0.7922 - val_loss: 0.6126
# Epoch 16/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7280 - loss: 0.5035 - val_accuracy: 0.6988 - val_loss: 0.6802
# Epoch 17/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7050 - loss: 0.5071 - val_accuracy: 0.5271 - val_loss: 0.7252
# Epoch 18/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7406 - loss: 0.4949 - val_accuracy: 0.7791 - val_loss: 0.6493
# Epoch 19/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7406 - loss: 0.4950 - val_accuracy: 0.8373 - val_loss: 0.5845
# Epoch 20/100
# 30/30 - 0s - 10ms/step - accuracy: 0.7218 - loss: 0.4930 - val_accuracy: 0.4588 - val_loss: 0.8260
# Epoch 21/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7280 - loss: 0.4917 - val_accuracy: 0.5201 - val_loss: 0.7362
# Epoch 22/100
# 30/30 - 0s - 9ms/step - accuracy: 0.
100
# 30/30 - 0s - 9ms/step - accuracy: 0.8243 - loss: 0.3498 - val_accuracy: 0.7239 - val_loss: 0.9557
# Epoch 86/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8180 - loss: 0.3539 - val_accuracy: 0.7329 - val_loss: 1.0632
# Epoch 87/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8452 - loss: 0.3403 - val_accuracy: 0.6767 - val_loss: 0.9816
# Epoch 88/100
# 30/30 - 0s - 10ms/step - accuracy: 0.7762 - loss: 0.3682 - val_accuracy: 0.5291 - val_loss: 1.0556
# Epoch 89/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8033 - loss: 0.3593 - val_accuracy: 0.7892 - val_loss: 0.9229
# Epoch 90/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8347 - loss: 0.3389 - val_accuracy: 0.5552 - val_loss: 1.0796
# Epoch 91/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8138 - loss: 0.3442 - val_accuracy: 0.7329 - val_loss: 0.9507
# Epoch 92/100
# 30/30 - 0s - 10ms/step - accuracy: 0.7887 - loss: 0.3498 - val_accuracy: 0.8173 - val_loss: 0.8249
# Epoch 93/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8159 - loss: 0.3449 - val_accuracy: 0.7801 - val_loss: 0.9512
# Epoch 94/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8138 - loss: 0.3449 - val_accuracy: 0.5472 - val_loss: 1.0940
# Epoch 95/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8201 - loss: 0.3446 - val_accuracy: 0.5934 - val_loss: 1.1030
# Epoch 96/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8159 - loss: 0.3458 - val_accuracy: 0.7942 - val_loss: 0.9585
# Epoch 97/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8201 - loss: 0.3357 - val_accuracy: 0.7339 - val_loss: 1.0231
# Epoch 98/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8222 - loss: 0.3334 - val_accuracy: 0.5873 - val_loss: 1.0445
# Epoch 99/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8054 - loss: 0.3318 - val_accuracy: 0.7108 - val_loss: 1.0329
# Epoch 100/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8054 - loss: 0.3425 - val_accuracy: 0.6797 - val_loss: 1.0354
# test loss: 1.0540761947631836
# Test accuracy: 0.6777108311653137

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy: 0.677710843373494
# Recall: 0.6907216494845361
# Precision: 0.1871508379888268
# F1 Score: 0.2945054945054945
# Micro F1 Score: 0.677710843373494
# Macro F1 Score: 0.542828544259904
# ROC AUC: 0.7443149891632168
# Confusion Matrix:
# [[608 291]
#  [ 30  67]]

# %% [markdown]
# ## undersampling, CNN-LSTM

# %%
# Feature column names
last1year_features = []
last2year_features = []
last3year_features = []
last4year_features = []
last5year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')
    last3year_features.append(f'X{i}_last3year')
    last4year_features.append(f'X{i}_last4year')
    last5year_features.append(f'X{i}_last5year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
X_last3year = data_cleaned[last3year_features].values
X_last4year = data_cleaned[last4year_features].values
X_last5year = data_cleaned[last5year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of X_last3year:", X_last3year.shape)
print("Shape of X_last4year:", X_last4year.shape)
print("Shape of X_last5year:", X_last5year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year, X_last3year, X_last4year,  X_last5year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)
X_last3year_scaled = scaler.transform(X_last3year)
X_last4year_scaled = scaler.transform(X_last4year)
X_last5year_scaled = scaler.transform(X_last5year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))
X_last3year_reshaped = np.reshape(X_last3year_scaled, (X_last3year_scaled.shape[0], 1, X_last3year_scaled.shape[1]))
X_last4year_reshaped = np.reshape(X_last4year_scaled, (X_last4year_scaled.shape[0], 1, X_last4year_scaled.shape[1]))
X_last5year_reshaped = np.reshape(X_last5year_scaled, (X_last5year_scaled.shape[0], 1, X_last5year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last5year_reshaped, X_last4year_reshaped, X_last3year_reshaped, X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_last3year_scaled:", X_last3year_scaled.shape)
print("Shape of X_last4year_scaled:", X_last4year_scaled.shape)
print("Shape of X_last5year_scaled:", X_last5year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)



# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)


from imblearn.under_sampling import RandomUnderSampler

# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply undersampling only on the training set
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 5, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)



from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.layers import Reshape, Conv1D, MaxPooling1D, Flatten, ZeroPadding1D



#Define input layer
inputs = Input(shape=(5, X_train_resampled.shape[2]))
# Reshape input to fit Conv1D layer
inputs_reshaped = Reshape((X_train_resampled.shape[2], 5))(inputs)  
# Define CNN-LSTM model
cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs_reshaped)
# Add Padding1D layer
padded_layer = ZeroPadding1D(padding=2)(cnn_layer)  #Consider flatten being divisible by the LSTM time step, so add padding
pooling_layer = MaxPooling1D(pool_size=2)(padded_layer)
flattened_layer = Flatten()(pooling_layer)
print("Shape of flattened_layer:", flattened_layer.shape)
reshaped_layer = Reshape((5, -1))(flattened_layer)  # Reshape the output to fit LSTM input  #The input shape expected by the LSTM layer is (timesteps, features)
lstm_layer = LSTM(100)(reshaped_layer)   
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)
# Define the model
model = Model(inputs=inputs, outputs=output_layer)
# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (4978, 18)
# Shape of X_last2year: (4978, 18)
# Shape of X_last3year: (4978, 18)
# Shape of X_last4year: (4978, 18)
# Shape of X_last5year: (4978, 18)
# Shape of y: (4978,)
# Shape of X_last1year_scaled: (4978, 18)
# Shape of X_last2year_scaled: (4978, 18)
# Shape of X_last3year_scaled: (4978, 18)
# Shape of X_last4year_scaled: (4978, 18)
# Shape of X_last5year_scaled: (4978, 18)
# Shape of X_combined_reshaped: (4978, 5, 18)
# Shape of X_train: (2986, 5, 18)
# Shape of X_val: (996, 5, 18)
# Shape of X_test: (996, 5, 18)
# Shape of X_train_resampled: (478, 90)
# Shape of X_train_resampled: (478, 5, 18)
# Shape of flattened_layer: (None, 640)
# Epoch 1/100
# 30/30 - 3s - 102ms/step - accuracy: 0.5167 - loss: 0.6926 - val_accuracy: 0.2942 - val_loss: 0.6801
# Epoch 2/100
# 30/30 - 0s - 11ms/step - accuracy: 0.5711 - loss: 0.6678 - val_accuracy: 0.2681 - val_loss: 0.7135
# Epoch 3/100
# 30/30 - 0s - 11ms/step - accuracy: 0.5774 - loss: 0.6592 - val_accuracy: 0.7912 - val_loss: 0.6492
# Epoch 4/100
# 30/30 - 0s - 11ms/step - accuracy: 0.6276 - loss: 0.6347 - val_accuracy: 0.7982 - val_loss: 0.6323
# Epoch 5/100
# 30/30 - 0s - 11ms/step - accuracy: 0.6276 - loss: 0.6190 - val_accuracy: 0.4257 - val_loss: 0.7075
# Epoch 6/100
# 30/30 - 0s - 12ms/step - accuracy: 0.6360 - loss: 0.5981 - val_accuracy: 0.3032 - val_loss: 0.8044
# Epoch 7/100
# 30/30 - 0s - 12ms/step - accuracy: 0.6548 - loss: 0.5869 - val_accuracy: 0.3122 - val_loss: 0.8458
# Epoch 8/100
# 30/30 - 0s - 11ms/step - accuracy: 0.6611 - loss: 0.5806 - val_accuracy: 0.7691 - val_loss: 0.6841
# Epoch 9/100
# 30/30 - 0s - 12ms/step - accuracy: 0.6862 - loss: 0.5620 - val_accuracy: 0.7851 - val_loss: 0.6611
# Epoch 10/100
# 30/30 - 0s - 12ms/step - accuracy: 0.7008 - loss: 0.5460 - val_accuracy: 0.7470 - val_loss: 0.6876
# Epoch 11/100
# 30/30 - 0s - 12ms/step - accuracy: 0.6820 - loss: 0.5360 - val_accuracy: 0.4237 - val_loss: 0.7846
# Epoch 12/100
# 30/30 - 0s - 12ms/step - accuracy: 0.7050 - loss: 0.5210 - val_accuracy: 0.8062 - val_loss: 0.6100
# Epoch 13/100
# 30/30 - 0s - 12ms/step - accuracy: 0.7092 - loss: 0.5184 - val_accuracy: 0.8002 - val_loss: 0.6916
# Epoch 14/100
# 30/30 - 0s - 13ms/step - accuracy: 0.6987 - loss: 0.5283 - val_accuracy: 0.6767 - val_loss: 0.8081
# Epoch 15/100
# 30/30 - 0s - 12ms/step - accuracy: 0.7259 - loss: 0.5096 - val_accuracy: 0.5773 - val_loss: 0.8029
# Epoch 16/100
# 30/30 - 0s - 11ms/step - accuracy: 0.7218 - loss: 0.4947 - val_accuracy: 0.4749 - val_loss: 0.8162
# Epoch 17/100
# 30/30 - 0s - 11ms/step - accuracy: 0.
100
# 30/30 - 0s - 11ms/step - accuracy: 0.8452 - loss: 0.2853 - val_accuracy: 0.6034 - val_loss: 1.6051
# Epoch 77/100
# 30/30 - 0s - 13ms/step - accuracy: 0.8891 - loss: 0.2628 - val_accuracy: 0.7851 - val_loss: 1.0640
# Epoch 78/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8452 - loss: 0.2788 - val_accuracy: 0.7992 - val_loss: 1.1738
# Epoch 79/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8494 - loss: 0.2813 - val_accuracy: 0.5120 - val_loss: 1.7764
# Epoch 80/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8661 - loss: 0.2676 - val_accuracy: 0.7400 - val_loss: 1.2509
# Epoch 81/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8389 - loss: 0.2846 - val_accuracy: 0.7721 - val_loss: 1.0805
# Epoch 82/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8682 - loss: 0.2573 - val_accuracy: 0.7279 - val_loss: 1.3413
# Epoch 83/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8682 - loss: 0.2521 - val_accuracy: 0.4769 - val_loss: 1.9600
# Epoch 84/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8368 - loss: 0.2824 - val_accuracy: 0.6647 - val_loss: 1.4600
# Epoch 85/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8745 - loss: 0.2511 - val_accuracy: 0.7008 - val_loss: 1.5091
# Epoch 86/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8703 - loss: 0.2409 - val_accuracy: 0.6898 - val_loss: 1.5366
# Epoch 87/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8556 - loss: 0.2579 - val_accuracy: 0.7992 - val_loss: 1.1145
# Epoch 88/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8326 - loss: 0.2894 - val_accuracy: 0.7962 - val_loss: 1.0125
# Epoch 89/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8808 - loss: 0.2634 - val_accuracy: 0.7661 - val_loss: 1.1310
# Epoch 90/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8703 - loss: 0.2505 - val_accuracy: 0.7761 - val_loss: 1.2897
# Epoch 91/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8598 - loss: 0.2624 - val_accuracy: 0.7831 - val_loss: 1.1511
# Epoch 92/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8536 - loss: 0.2599 - val_accuracy: 0.6757 - val_loss: 1.3970
# Epoch 93/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8787 - loss: 0.2482 - val_accuracy: 0.7530 - val_loss: 1.3405
# Epoch 94/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8745 - loss: 0.2333 - val_accuracy: 0.7641 - val_loss: 1.5554
# Epoch 95/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8891 - loss: 0.2547 - val_accuracy: 0.7159 - val_loss: 1.5289
# Epoch 96/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8745 - loss: 0.2474 - val_accuracy: 0.7861 - val_loss: 1.2478
# Epoch 97/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8619 - loss: 0.2440 - val_accuracy: 0.6044 - val_loss: 1.9508
# Epoch 98/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8787 - loss: 0.2167 - val_accuracy: 0.7641 - val_loss: 1.4118
# Epoch 99/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8996 - loss: 0.2133 - val_accuracy: 0.6647 - val_loss: 1.8836
# Epoch 100/100
# 30/30 - 0s - 11ms/step - accuracy: 0.8808 - loss: 0.2244 - val_accuracy: 0.7169 - val_loss: 1.6123
# test loss: 1.608925461769104
# Test accuracy: 0.7449799180030823

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Accuracy: 0.7449799196787149
# Recall: 0.5773195876288659
# Precision: 0.20817843866171004
# F1 Score: 0.30601092896174864
# Micro F1 Score: 0.7449799196787149
# Macro F1 Score: 0.5748996834230637
# ROC AUC: 0.7249406557113861
# Confusion Matrix:
# [[686 213]
#  [ 41  56]]
