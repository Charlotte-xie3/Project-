# %%
#LSTM

# %%
import pandas as pd

# Read the data set
data = pd.read_csv("new_df_selected2_last2years_adjusted.csv")


unique_company_names = data['company_name'].nunique()
unique_status_labels = data['status_label'].nunique()
unique_divisions = data['Division'].nunique()
unique_majorgroup = data['MajorGroup'].nunique()
unique_last_year = data['last_year'].nunique()

print("Number of unique values in 'company_name' column:", unique_company_names)
print("Number of unique values in 'status_label' column:", unique_status_labels)
print("Number of unique values in 'Division' column:", unique_divisions)
print("Number of unique values in 'MajorGroup' column:", unique_majorgroup)
print("Number of unique values in 'last_year' column:", unique_last_year)
# Out:
# Number of unique values in 'company_name' column: 8971
# Number of unique values in 'status_label' column: 2
# Number of unique values in 'Division' column: 10
# Number of unique values in 'MajorGroup' column: 73
# Number of unique values in 'last_year' column: 20

# %%
data.shape
# Out:
# (8971, 81)

# %%
# Encoding non-numeric columns

from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder object
label_encoder = LabelEncoder()


# Label-encode the company_name column
data['company_name_encoded'] = label_encoder.fit_transform(data['company_name'])


# Label-encode the Division column
data['Division_encoded'] = label_encoder.fit_transform(data['Division'])

# Label-encode MajorGroup columns
data['MajorGroup_encoded'] = label_encoder.fit_transform(data['MajorGroup'])
#When using label encoding for feature encoding, the sequential relationship between categories will not be introduced and will not have an impact on prediction.

# Encode the label of the status_label column
data['status_label_encoded'] = label_encoder.fit_transform(data['status_label'])
#With only two categories, it may be simpler and more appropriate to use label encoding as it maps the categories to 0 and 1, suitable for use in tree-based models. 
#If use one-hot encoding, a new column will be generated

print(data.head())
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#   company_name status_label Division  MajorGroup  last_year  X1_last1year  \
# 0          C_1        alive        D          37     2017.0         942.7
# 1          C_2        alive        D          36     2010.0        1107.7
# 2          C_3        alive        D          38     2008.0       12686.0
# 3          C_4        alive        D          28     2007.0      581502.0
# 4          C_5        alive        D          35     1999.0       28957.0
#
#    X1_last2year  X2_last1year  X2_last2year  X3_last1year  ...  \
# 0         888.5       1524.70        1504.1       1413.20  ...
# 1         900.2       1474.50        1343.6        677.20  ...
# 2       13454.0      21401.00       27171.0      19334.00  ...
# 3      353541.0    1288165.00      927239.0        267.81  ...
# 4           NaN         42.21           NaN      79567.00  ...
#
#    X18_last1year_ycr  X18_last2year_ycr  nyse_last1year  nyse_last2year  \
# 0           0.001482           0.061414    11912.848307    10451.377523
# 1           0.135088          -0.289221     7166.229940     6100.795776
# 2           0.269244           0.227659     8001.502441     9685.001790
# 3          -0.998676           0.318548     9685.001790     8434.441610
# 4                NaN                NaN     6549.827474             NaN
#
#    nasdaq_last1year  nasdaq_last2year  company_name_encoded  Division_encoded  \
# 0       6293.024211       5015.926717                     0                 3
# 1       2333.908345       1856.529999                  1111                 3
# 2       2148.948334       2587.587504                  2222                 3
# 3       2587.587504       2278.996664                  3333                 3
# 4       2787.559998               NaN                  4444                 3
#
#    MajorGroup_encoded  status_label_encoded
# 0                  29                     0
# 1                  28                     0
# 2                  30                     0
# 3                  20                     0
# 4                  27                     0
#
# [5 rows x 85 columns]

# %%
data.shape
# Out:
# (8971, 85)

# %%
missing_rows_count = data.isnull().any(axis=1).sum()
print("Number of rows with missing values:", missing_rows_count)
# Out:
# Number of rows with missing values: 1870

# %%
# Delete rows with missing values
data_cleaned = data.dropna()
# Delete non-numeric columns that are not encoded
# List of static columns to drop
static_columns_to_drop = [
    'company_name', 'status_label', 'Division', 'MajorGroup', 'last_year', 'company_name_encoded',
    'Division_encoded', 'MajorGroup_encoded'
]

# List of dynamic columns to drop (nyse and nasdaq columns for 1 year and 2 years)
nyse_nasdaq_columns_to_drop = [f'{exchange}_last{year}year' for exchange in ('nyse', 'nasdaq') for year in (1, 2)]

# Add X1_last1year_ycr to X18_last1year_ycr and X1_last2year_ycr to X18_last2year_ycr columns to the list
ycr_columns_to_drop = [f'X{i}_last{year}year_ycr' for i in range(1, 19) for year in (1, 2)]

# Combine all columns to drop
columns_to_drop = static_columns_to_drop + nyse_nasdaq_columns_to_drop + ycr_columns_to_drop

# Drop the columns from the data
data_cleaned = data_cleaned.drop(columns=columns_to_drop)


data_cleaned.shape
# Out:
# (7101, 37)

# %%
data_cleaned.head
# Out:
# <bound method NDFrame.head of       X1_last1year  X1_last2year  X2_last1year  X2_last2year  X3_last1year  \
# 0            942.7         888.5       1524.70       1504.10       1413.20
# 1           1107.7         900.2       1474.50       1343.60        677.20
# 2          12686.0       13454.0      21401.00      27171.00      19334.00
# 3         581502.0      353541.0    1288165.00     927239.00        267.81
# 5           6838.0        6642.0      25088.00      25438.00      18138.00
# ...            ...           ...           ...           ...           ...
# 8966       10566.0       11738.0      28278.00      26206.00      31288.00
# 8967        3369.0        9049.0       3466.00       9198.00        208.00
# 8968        2482.2        2340.6       9401.50      10252.40        966.70
# 8969         931.6        1032.7       2810.20       2542.00       1475.90
# 8970       82589.0      135207.0       1625.37       1736.11      68817.00
#
#       X3_last2year  X4_last1year  X4_last2year  X5_last1year  X5_last2year  \
# 0         1422.700         177.2         155.3        40.500        71.000
# 1          600.500         650.8         651.0        61.500        66.400
# 2           17.589          23.0        5822.0      1686.000         0.500
# 3       229115.000         300.0           0.0     46338.000        42.873
# 5        16935.000        9253.0       10583.0       995.000      1007.000
# ...            ...           ...           ...           ...           ...
# 8966     26885.000        8497.0        8549.0      1200.000      1133.000
# 8967      1077.000           0.0           0.0        57.000         0.190
# 8968      1833.200        5350.7        5440.6       156.600       354.200
# 8969      1269.600        1409.5        1442.3        82.500        62.100
# 8970     66527.000      632122.0      694035.0        65.201        65.330
#
#       ...  X14_last2year  X15_last1year  X15_last2year  X16_last1year  \
# 0     ...        1767.60   1.551458e+06      1200.3288          588.4
# 1     ...         996.70   1.231524e+06       805.6440         1040.1
# 2     ...          28.72   5.020100e+00        30.4793        17224.0
# 3     ...      653828.00   8.824491e+02      1038.6859       557038.0
# 5     ...       19917.00   2.597575e+03      2571.1835        29033.0
# ...   ...            ...            ...            ...            ...
# 8966  ...       34484.00   3.124296e+04     43522.5638        17882.0
# 8967  ...         545.00   2.231000e-01         0.1309         7181.0
# 8968  ...        3775.90   2.985101e+03      2850.9981         7220.4
# 8969  ...        2408.20   7.543515e+03      7563.1327         2156.2
# 8970  ...      161884.00   3.541786e+02       412.6241       712687.0
#
#       X16_last2year  X17_last1year  X17_last2year  X18_last1year  \
# 0            589.90        1748.30        1767.60       1621.800
# 1            987.40        1156.60         996.70       1035.200
# 2          12296.00          34.28          28.72      37001.000
# 3            203.24      722425.00      653828.00        681.609
# 5          28927.00       22170.00       19917.00      20867.000
# ...             ...            ...            ...            ...
# 8966       17256.00       39004.00       34484.00      32459.000
# 8967        2408.00          53.00         545.00         10.700
# 8968        7392.40        1961.00        3775.90       1548.300
# 8969        2136.50        2731.70        2408.20       2112.700
# 8970      776697.00      160513.00      161884.00      93251.000
#
#       X18_last2year  status_label_encoded
# 0            1619.4                     0
# 1             912.0                     0
# 2           29152.0                     0
# 3          514914.0                     0
# 5           19655.0                     1
# ...             ...                   ...
# 8966        27850.0                     0
# 8967        13328.0                     0
# 8968         3017.8                     0
# 8969         1840.9                     0
# 8970        92713.0                     0
#
# [7101 rows x 37 columns]>

# %%
status_counts = data_cleaned['status_label_encoded'].value_counts()
print(status_counts)
# Out:
# 0    6537
# 1     564
# Name: status_label_encoded, dtype: int64

# %%
#the impact of imbalanced datasets

# %% [markdown]
# ### 1.1 imbalance dataset

# %%
# Feature column names
last1year_features = []
last2year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')




# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)



# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)




from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(2, X_train.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (7101, 18)
# Shape of X_last2year: (7101, 18)
# Shape of y: (7101,)
# Shape of X_last1year_scaled: (7101, 18)
# Shape of X_last2year_scaled: (7101, 18)
# Shape of X_combined_reshaped: (7101, 2, 18)
# Shape of X_train: (4260, 2, 18)
# Shape of X_val: (1420, 2, 18)
# Shape of X_test: (1421, 2, 18)
# Epoch 1/100
# 267/267 - 3s - 13ms/step - accuracy: 0.9012 - loss: 0.3397 - val_accuracy: 0.9225 - val_loss: 0.2532
# Epoch 2/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9195 - loss: 0.2600 - val_accuracy: 0.9218 - val_loss: 0.2467
# Epoch 3/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9216 - loss: 0.2545 - val_accuracy: 0.9204 - val_loss: 0.2440
# Epoch 4/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9223 - loss: 0.2510 - val_accuracy: 0.9232 - val_loss: 0.2422
# Epoch 5/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9221 - loss: 0.2476 - val_accuracy: 0.9232 - val_loss: 0.2416
# Epoch 6/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9223 - loss: 0.2446 - val_accuracy: 0.9239 - val_loss: 0.2408
# Epoch 7/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9242 - loss: 0.2434 - val_accuracy: 0.9218 - val_loss: 0.2400
# Epoch 8/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9246 - loss: 0.2416 - val_accuracy: 0.9254 - val_loss: 0.2385
# Epoch 9/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9249 - loss: 0.2424 - val_accuracy: 0.9218 - val_loss: 0.2382
# Epoch 10/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9258 - loss: 0.2388 - val_accuracy: 0.9254 - val_loss: 0.2371
# Epoch 11/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9249 - loss: 0.2376 - val_accuracy: 0.9254 - val_loss: 0.2383
# Epoch 12/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9254 - loss: 0.2342 - val_accuracy: 0.9239 - val_loss: 0.2413
# Epoch 13/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9246 - loss: 0.2338 - val_accuracy: 0.9254 - val_loss: 0.2361
# Epoch 14/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9258 - loss: 0.2320 - val_accuracy: 0.9254 - val_loss: 0.2360
# Epoch 15/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9246 - loss: 0.2309 - val_accuracy: 0.9261 - val_loss: 0.2399
# Epoch 16/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9263 - loss: 0.2297 - val_accuracy: 0.9232 - val_loss: 0.2388
# Epoch 17/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9265 - loss: 0.2276 - val_accuracy: 0.9261 - val_loss: 0.2356
# Epoch 18/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9254 - loss: 0.2271 - val_accuracy: 0.9261 - val_loss: 0.2370
# Epoch 19/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9277 - loss: 0.2265 - val_accuracy: 0.9246 - val_loss: 0.2407
# Epoch 20/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9261 - loss: 0.2253 - val_accuracy: 0.9254 - val_loss: 0.2397
# Epoch 21/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9277 - loss: 0.2244 - val_accuracy: 0.9254 - val_loss: 0.2395
# Epoch 22/100
# 267/267 - 1s - 3ms/step - accuracy: 0.
100
# 267/267 - 1s - 3ms/step - accuracy: 0.9423 - loss: 0.1828 - val_accuracy: 0.9197 - val_loss: 0.3099
# Epoch 86/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9423 - loss: 0.1816 - val_accuracy: 0.9197 - val_loss: 0.3113
# Epoch 87/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9427 - loss: 0.1815 - val_accuracy: 0.9183 - val_loss: 0.3129
# Epoch 88/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9430 - loss: 0.1806 - val_accuracy: 0.9218 - val_loss: 0.3132
# Epoch 89/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9427 - loss: 0.1785 - val_accuracy: 0.9197 - val_loss: 0.3127
# Epoch 90/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9434 - loss: 0.1801 - val_accuracy: 0.9225 - val_loss: 0.3128
# Epoch 91/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9420 - loss: 0.1797 - val_accuracy: 0.9204 - val_loss: 0.3148
# Epoch 92/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9425 - loss: 0.1771 - val_accuracy: 0.9232 - val_loss: 0.3163
# Epoch 93/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9432 - loss: 0.1797 - val_accuracy: 0.9225 - val_loss: 0.3200
# Epoch 94/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9432 - loss: 0.1771 - val_accuracy: 0.9218 - val_loss: 0.3203
# Epoch 95/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9437 - loss: 0.1788 - val_accuracy: 0.9218 - val_loss: 0.3204
# Epoch 96/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9446 - loss: 0.1765 - val_accuracy: 0.9190 - val_loss: 0.3211
# Epoch 97/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9444 - loss: 0.1765 - val_accuracy: 0.9176 - val_loss: 0.3305
# Epoch 98/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9437 - loss: 0.1764 - val_accuracy: 0.9176 - val_loss: 0.3261
# Epoch 99/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9439 - loss: 0.1770 - val_accuracy: 0.9190 - val_loss: 0.3313
# Epoch 100/100
# 267/267 - 1s - 3ms/step - accuracy: 0.9444 - loss: 0.1729 - val_accuracy: 0.9211 - val_loss: 0.3278
# test loss: 0.34107065200805664
# Test accuracy: 0.9190710783004761

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Accuracy: 0.9190710767065446
# Recall: 0.10526315789473684
# Precision: 0.48
# F1 Score: 0.1726618705035971
# Micro F1 Score: 0.9190710767065446
# Macro F1 Score: 0.5650582752443993
# ROC AUC: 0.6872642585806521
# Confusion Matrix:
# [[1294   13]
#  [ 102   12]]

# %% [markdown]
# ### 1.2 SMOTE

# %%
# Feature column names
last1year_features = []
last2year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)



# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)



from imblearn.over_sampling import SMOTE
# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply SMOTE only on the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 2, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)



from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(2, X_train_resampled.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (7101, 18)
# Shape of X_last2year: (7101, 18)
# Shape of y: (7101,)
# Shape of X_last1year_scaled: (7101, 18)
# Shape of X_last2year_scaled: (7101, 18)
# Shape of X_combined_reshaped: (7101, 2, 18)
# Shape of X_train: (4260, 2, 18)
# Shape of X_val: (1420, 2, 18)
# Shape of X_test: (1421, 2, 18)
# Shape of X_train_resampled: (7838, 36)
# Shape of X_train_resampled: (7838, 2, 18)
# Epoch 1/100
# 490/490 - 4s - 7ms/step - accuracy: 0.6498 - loss: 0.6231 - val_accuracy: 0.8007 - val_loss: 0.5603
# Epoch 2/100
# 490/490 - 1s - 3ms/step - accuracy: 0.6793 - loss: 0.5764 - val_accuracy: 0.8345 - val_loss: 0.4931
# Epoch 3/100
# 490/490 - 1s - 3ms/step - accuracy: 0.6969 - loss: 0.5539 - val_accuracy: 0.7211 - val_loss: 0.5617
# Epoch 4/100
# 490/490 - 1s - 3ms/step - accuracy: 0.
100
# 490/490 - 1s - 3ms/step - accuracy: 0.8570 - loss: 0.2897 - val_accuracy: 0.8070 - val_loss: 0.6909
# Epoch 89/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8553 - loss: 0.2860 - val_accuracy: 0.7852 - val_loss: 0.7175
# Epoch 90/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8566 - loss: 0.2883 - val_accuracy: 0.8070 - val_loss: 0.6934
# Epoch 91/100
# 490/490 - 2s - 3ms/step - accuracy: 0.8546 - loss: 0.2863 - val_accuracy: 0.8444 - val_loss: 0.6589
# Epoch 92/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8571 - loss: 0.2856 - val_accuracy: 0.8620 - val_loss: 0.6302
# Epoch 93/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8589 - loss: 0.2824 - val_accuracy: 0.8261 - val_loss: 0.6847
# Epoch 94/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8583 - loss: 0.2815 - val_accuracy: 0.7662 - val_loss: 0.7497
# Epoch 95/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8614 - loss: 0.2796 - val_accuracy: 0.6606 - val_loss: 0.8371
# Epoch 96/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8570 - loss: 0.2767 - val_accuracy: 0.8338 - val_loss: 0.6853
# Epoch 97/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8623 - loss: 0.2794 - val_accuracy: 0.8296 - val_loss: 0.6820
# Epoch 98/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8622 - loss: 0.2769 - val_accuracy: 0.8289 - val_loss: 0.6928
# Epoch 99/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8653 - loss: 0.2756 - val_accuracy: 0.8113 - val_loss: 0.7143
# Epoch 100/100
# 490/490 - 1s - 3ms/step - accuracy: 0.8636 - loss: 0.2747 - val_accuracy: 0.7641 - val_loss: 0.7628
# test loss: 0.7479634881019592
# Test accuracy: 0.7572132349014282

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Accuracy: 0.757213230119634
# Recall: 0.47368421052631576
# Precision: 0.1592920353982301
# F1 Score: 0.23841059602649006
# Micro F1 Score: 0.7572132301196339
# Macro F1 Score: 0.5469993541036594
# ROC AUC: 0.6749218110310204
# Confusion Matrix:
# [[1022  285]
#  [  60   54]]

# %% [markdown]
# ### 1.3  Undersampling

# %%
# Feature column names
last1year_features = []
last2year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)


# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)



from imblearn.under_sampling import RandomUnderSampler

# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply undersampling only on the training set
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 2, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)




from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam

# Define LSTM model
inputs = Input(shape=(2, X_train_resampled.shape[2]))  # (2, number of features) Accepts data with two time steps as input, and the first time step is the data of the past two years and the second time step is the data of the past year.
lstm_layer = LSTM(100)(inputs)
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

model = Model(inputs=inputs, outputs=output_layer)

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (7101, 18)
# Shape of X_last2year: (7101, 18)
# Shape of y: (7101,)
# Shape of X_last1year_scaled: (7101, 18)
# Shape of X_last2year_scaled: (7101, 18)
# Shape of X_combined_reshaped: (7101, 2, 18)
# Shape of X_train: (4260, 2, 18)
# Shape of X_val: (1420, 2, 18)
# Shape of X_test: (1421, 2, 18)
# Shape of X_train_resampled: (682, 36)
# Shape of X_train_resampled: (682, 2, 18)
# Epoch 1/100
# 43/43 - 2s - 55ms/step - accuracy: 0.5425 - loss: 0.6847 - val_accuracy: 0.2690 - val_loss: 0.7032
# Epoch 2/100
# 43/43 - 0s - 7ms/step - accuracy: 0.6070 - loss: 0.6557 - val_accuracy: 0.4014 - val_loss: 0.6700
# Epoch 3/100
# 43/43 - 0s - 7ms/step - accuracy: 0.6540 - loss: 0.6367 - val_accuracy: 0.3958 - val_loss: 0.6706
# Epoch 4/100
# 43/43 - 0s - 7ms/step - accuracy: 0.6657 - loss: 0.6196 - val_accuracy: 0.6204 - val_loss: 0.6507
# Epoch 5/100
# 43/43 - 0s - 8ms/step - accuracy: 0.6525 - loss: 0.6128 - val_accuracy: 0.5303 - val_loss: 0.6507
# Epoch 6/100
# 43/43 - 0s - 7ms/step - accuracy: 0.
100
# 43/43 - 0s - 7ms/step - accuracy: 0.7361 - loss: 0.4427 - val_accuracy: 0.8035 - val_loss: 0.7549
# Epoch 95/100
# 43/43 - 0s - 6ms/step - accuracy: 0.7522 - loss: 0.4434 - val_accuracy: 0.7845 - val_loss: 0.7970
# Epoch 96/100
# 43/43 - 0s - 7ms/step - accuracy: 0.7654 - loss: 0.4297 - val_accuracy: 0.7810 - val_loss: 0.8017
# Epoch 97/100
# 43/43 - 0s - 7ms/step - accuracy: 0.7698 - loss: 0.4290 - val_accuracy: 0.7746 - val_loss: 0.8232
# Epoch 98/100
# 43/43 - 0s - 7ms/step - accuracy: 0.7610 - loss: 0.4340 - val_accuracy: 0.4972 - val_loss: 0.9508
# Epoch 99/100
# 43/43 - 0s - 7ms/step - accuracy: 0.7493 - loss: 0.4463 - val_accuracy: 0.8099 - val_loss: 0.7736
# Epoch 100/100
# 43/43 - 0s - 6ms/step - accuracy: 0.7551 - loss: 0.4364 - val_accuracy: 0.7965 - val_loss: 0.7993
# test loss: 0.8140636086463928
# Test accuracy: 0.797325849533081

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Accuracy: 0.7973258268824771
# Recall: 0.47368421052631576
# Precision: 0.19148936170212766
# F1 Score: 0.2727272727272727
# Micro F1 Score: 0.7973258268824771
# Macro F1 Score: 0.577492009217275
# ROC AUC: 0.734697781178271
# Confusion Matrix:
# [[1079  228]
#  [  60   54]]

# %% [markdown]
# ## undersampling, CNN-LSTM

# %%
# Feature column names
last1year_features = []
last2year_features = []

# Loop to build list of feature column names
for i in range(1, 19):
    last1year_features.append(f'X{i}_last1year')
    last2year_features.append(f'X{i}_last2year')

# Define target column name
target_column = 'status_label_encoded'

# Extract features and target
X_last1year = data_cleaned[last1year_features].values
X_last2year = data_cleaned[last2year_features].values
y = data_cleaned[target_column].values

# Print data structure
print("Shape of X_last1year:", X_last1year.shape)
print("Shape of X_last2year:", X_last2year.shape)
print("Shape of y:", y.shape)



# Data Standardization
import numpy as np
from sklearn.preprocessing import StandardScaler

# Define the scaler
scaler = StandardScaler()
# Fit the scaler on the entire data set
scaler.fit(np.concatenate((X_last1year, X_last2year), axis=0))
# Transform each year's data using the same scaler
X_last1year_scaled = scaler.transform(X_last1year)
X_last2year_scaled = scaler.transform(X_last2year)

# Reshape features to 3D arrays [samples, time steps, features]
X_last1year_reshaped = np.reshape(X_last1year_scaled, (X_last1year_scaled.shape[0], 1, X_last1year_scaled.shape[1]))
X_last2year_reshaped = np.reshape(X_last2year_scaled, (X_last2year_scaled.shape[0], 1, X_last2year_scaled.shape[1]))

# Combine last1year and last2year features along the time step dimension
X_combined_reshaped = np.concatenate((X_last2year_reshaped, X_last1year_reshaped), axis=1)
#First use data from the past two years (X_last3year_reshaped), then data from the past years 

# Print data structure
print("Shape of X_last1year_scaled:", X_last1year_scaled.shape)
print("Shape of X_last2year_scaled:", X_last2year_scaled.shape)
print("Shape of X_combined_reshaped:", X_combined_reshaped.shape)

# Split into train, validation, and test sets
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_reshaped, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.8 * 0.25 = 0.2

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)


from imblearn.under_sampling import RandomUnderSampler

# Flatten X_train
X_train_flat = X_train.reshape(X_train.shape[0], -1)
# Apply undersampling only on the training set
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train_flat, y_train)
print("Shape of X_train_resampled:", X_train_resampled.shape)
# Reshape resampled training data to match LSTM input shape
X_train_resampled = X_train_resampled.reshape(-1, 2, X_train.shape[2])
# Check the shape of resampled data and target variable
print("Shape of X_train_resampled:", X_train_resampled.shape)



from keras.layers import LSTM, Dense, Dropout, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.layers import Reshape, Conv1D, MaxPooling1D, Flatten, ZeroPadding1D



#Define input layer
inputs = Input(shape=(2, X_train_resampled.shape[2]))
# Reshape input to fit Conv1D layer
inputs_reshaped = Reshape((X_train_resampled.shape[2], 2))(inputs)  
# Define CNN-LSTM model
cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs_reshaped)
# Add Padding1D layer
padded_layer = ZeroPadding1D(padding=2)(cnn_layer)  #Consider flatten being divisible by the LSTM time step, so add padding
pooling_layer = MaxPooling1D(pool_size=2)(padded_layer)
flattened_layer = Flatten()(pooling_layer)
print("Shape of flattened_layer:", flattened_layer.shape)
reshaped_layer = Reshape((2, -1))(flattened_layer)  # Reshape the output to fit LSTM input  #The input shape expected by the LSTM layer is (timesteps, features)
lstm_layer = LSTM(100)(reshaped_layer)   
dropout_layer = Dropout(0.2)(lstm_layer)
output_layer = Dense(1, activation='sigmoid')(dropout_layer)
# Define the model
model = Model(inputs=inputs, outputs=output_layer)
# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=2)

## Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Shape of X_last1year: (7101, 18)
# Shape of X_last2year: (7101, 18)
# Shape of y: (7101,)
# Shape of X_last1year_scaled: (7101, 18)
# Shape of X_last2year_scaled: (7101, 18)
# Shape of X_combined_reshaped: (7101, 2, 18)
# Shape of X_train: (4260, 2, 18)
# Shape of X_val: (1420, 2, 18)
# Shape of X_test: (1421, 2, 18)
# Shape of X_train_resampled: (682, 36)
# Shape of X_train_resampled: (682, 2, 18)
# Shape of flattened_layer: (None, 640)
# Epoch 1/100
# 43/43 - 3s - 71ms/step - accuracy: 0.5660 - loss: 0.6750 - val_accuracy: 0.2937 - val_loss: 0.7008
# Epoch 2/100
# 43/43 - 0s - 9ms/step - accuracy: 0.6217 - loss: 0.6458 - val_accuracy: 0.8394 - val_loss: 0.6138
# Epoch 3/100
# 43/43 - 0s - 9ms/step - accuracy: 0.6349 - loss: 0.6250 - val_accuracy: 0.4275 - val_loss: 0.6910
# Epoch 4/100
# 43/43 - 0s - 10ms/step - accuracy: 0.6408 - loss: 0.6166 - val_accuracy: 0.4373 - val_loss: 0.6633
100
# 43/43 - 0s - 9ms/step - accuracy: 0.8094 - loss: 0.3686 - val_accuracy: 0.4810 - val_loss: 1.3298
# Epoch 81/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8152 - loss: 0.3641 - val_accuracy: 0.6148 - val_loss: 0.9711
# Epoch 82/100
# 43/43 - 1s - 12ms/step - accuracy: 0.8152 - loss: 0.3562 - val_accuracy: 0.7606 - val_loss: 1.0499
# Epoch 83/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8094 - loss: 0.3547 - val_accuracy: 0.7458 - val_loss: 0.9720
# Epoch 84/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8226 - loss: 0.3358 - val_accuracy: 0.8197 - val_loss: 0.8716
# Epoch 85/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8094 - loss: 0.3462 - val_accuracy: 0.6746 - val_loss: 0.9643
# Epoch 86/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8094 - loss: 0.3658 - val_accuracy: 0.5113 - val_loss: 1.3608
# Epoch 87/100
# 43/43 - 0s - 9ms/step - accuracy: 0.7918 - loss: 0.3704 - val_accuracy: 0.6873 - val_loss: 1.1414
# Epoch 88/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8226 - loss: 0.3407 - val_accuracy: 0.6923 - val_loss: 1.1511
# Epoch 89/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8328 - loss: 0.3394 - val_accuracy: 0.8134 - val_loss: 0.9353
# Epoch 90/100
# 43/43 - 0s - 10ms/step - accuracy: 0.8152 - loss: 0.3482 - val_accuracy: 0.7669 - val_loss: 1.0473
# Epoch 91/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8123 - loss: 0.3386 - val_accuracy: 0.6592 - val_loss: 1.1772
# Epoch 92/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8270 - loss: 0.3357 - val_accuracy: 0.7035 - val_loss: 1.1143
# Epoch 93/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8314 - loss: 0.3283 - val_accuracy: 0.6092 - val_loss: 1.2193
# Epoch 94/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8299 - loss: 0.3342 - val_accuracy: 0.6923 - val_loss: 1.1662
# Epoch 95/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8240 - loss: 0.3340 - val_accuracy: 0.7754 - val_loss: 1.0675
# Epoch 96/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8138 - loss: 0.3344 - val_accuracy: 0.7268 - val_loss: 1.1714
# Epoch 97/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8343 - loss: 0.3229 - val_accuracy: 0.8106 - val_loss: 0.9809
# Epoch 98/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8328 - loss: 0.3278 - val_accuracy: 0.5514 - val_loss: 1.4152
# Epoch 99/100
# 43/43 - 0s - 9ms/step - accuracy: 0.8255 - loss: 0.3324 - val_accuracy: 0.6528 - val_loss: 1.3617
# Epoch 100/100
# 43/43 - 0s - 9ms/step - accuracy: 0.7859 - loss: 0.3572 - val_accuracy: 0.4838 - val_loss: 1.5864
# test loss: 1.493027687072754
# Test accuracy: 0.4588318169116974

# %%
# Make predictions on the test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

# Calculate micro F1 score
micro_f1 = f1_score(y_test, y_pred, average='micro')

# Calculate macro F1 score
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
print("Micro F1 Score:", micro_f1)
print("Macro F1 Score:", macro_f1)
print("ROC AUC:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy: 0.45883180858550315
# Recall: 0.8245614035087719
# Precision: 0.11150652431791222
# F1 Score: 0.19644723092998956
# Micro F1 Score: 0.45883180858550315
# Macro F1 Score: 0.3942448356241459
# ROC AUC: 0.7176472167411644
# Confusion Matrix:
# [[558 749]
#  [ 20  94]]
